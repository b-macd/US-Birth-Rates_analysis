# %%
import pandas as pd
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

birth_rates_df = pd.read_csv("data/us_births_2016_2021.csv")
new_df = pd.read_csv('data/Natality, 2007-2021.txt',header=0,delimiter="\t")

# %%
new_df1 = new_df.drop(columns=['Notes', 'Year Code', 'State Code'])
new_df1
# Out:
#         State  Year Marital Status Marital Status Code            Tobacco Use  \
# 0     Alabama  2007        Married                   1           Not Reported
# 1     Alabama  2007        Married                   1           Not Reported
# 2     Alabama  2007        Married                   1           Not Reported
# 3     Alabama  2007      Unmarried                   2           Not Reported
# 4     Alabama  2007      Unmarried                   2           Not Reported
# ...       ...   ...            ...                 ...                    ...
# 8170  Wyoming  2021      Unmarried                   2                    Yes
# 8171  Wyoming  2021      Unmarried                   2                     No
# 8172  Wyoming  2021      Unmarried                   2                     No
# 8173  Wyoming  2021      Unmarried                   2  Unknown or Not Stated
# 8174  Wyoming  2021      Unmarried                   2  Unknown or Not Stated
#
#       Tobacco Use Code               Diabetes  Diabetes Code  Births  \
# 0                   10                    Yes              1    2016
# 1                   10                     No              2   37845
# 2                   10  Unknown or Not Stated              9     103
# 3                   10                    Yes              1     786
# 4                   10                     No              2   24016
# ...                ...                    ...            ...     ...
# 8170                 1                     No              2     348
# 8171                 2                    Yes              1      99
# 8172                 2                     No              2    1416
# 8173                 9                    Yes              1      11
# 8174                 9                     No              2     149
#
#      % of Total Births Average Birth Weight  Average Age of Mother
# 0                0.00%              3333.52                  30.25
# 1                0.06%              3244.50                  27.61
# 2                0.00%              3325.40                  26.62
# 3                0.00%              3183.51                  26.50
# 4                0.04%              3055.34                  22.92
# ...                ...                  ...                    ...
# 8170             0.00%              3007.87                  26.24
# 8171             0.00%              3155.60                  28.46
# 8172             0.00%              3129.75                  25.08
# 8173             0.00%              3167.00                  29.91
# 8174             0.00%              3082.24                  25.70
#
# [8175 rows x 12 columns]

# %%
birth_rates_df.head(10)
# Out:
#      State State Abbreviation  Year Gender  \
# 0  Alabama                 AL  2016      F
# 1  Alabama                 AL  2016      F
# 2  Alabama                 AL  2016      F
# 3  Alabama                 AL  2016      F
# 4  Alabama                 AL  2016      F
# 5  Alabama                 AL  2016      F
# 6  Alabama                 AL  2016      F
# 7  Alabama                 AL  2016      F
# 8  Alabama                 AL  2016      F
# 9  Alabama                 AL  2016      M
#
#                            Education Level of Mother  Education Level Code  \
# 0                                  8th grade or less                     1
# 1             9th through 12th grade with no diploma                     2
# 2              High school graduate or GED completed                     3
# 3              Some college credit, but not a degree                     4
# 4                          Associate degree (AA, AS)                     5
# 5                     Bachelor's degree (BA, AB, BS)                     6
# 6      Master's degree (MA, MS, MEng, MEd, MSW, MBA)                     7
# 7  Doctorate (PhD, EdD) or Professional Degree (M...                     8
# 8                              Unknown or Not Stated                    -9
# 9                                  8th grade or less                     1
#
#    Number of Births  Average Age of Mother (years)  Average Birth Weight (g)
# 0              1052                           27.8                    3116.9
# 1              3436                           24.1                    3040.0
# 2              8777                           25.4                    3080.0
# 3              6453                           26.7                    3121.9
# 4              2227                           28.9                    3174.3
# 5              4453                           30.3                    3239.0
# 6              1910                           32.0                    3263.5
# 7               487                           33.1                    3196.7
# 8                65                           27.7                    3083.9
# 9              1188                           27.6                    3232.9

# %%
birth_rates_df.shape
# Out:
# (5496, 9)

# %%
birth_rates_df.describe()
# Out:
#               Year  Education Level Code  Number of Births  \
# count  5496.000000           5496.000000       5496.000000
# mean   2018.500728              3.026201       4115.443959
# std       1.707554              4.733406       6687.036797
# min    2016.000000             -9.000000         10.000000
# 25%    2017.000000              2.000000        559.000000
# 50%    2019.000000              4.000000       1692.000000
# 75%    2020.000000              6.000000       5140.000000
# max    2021.000000              8.000000      59967.000000
#
#        Average Age of Mother (years)  Average Birth Weight (g)
# count                    5496.000000               5496.000000
# mean                       29.552274               3250.887627
# std                         2.779735                114.456090
# min                        23.100000               2451.900000
# 25%                        27.500000               3182.200000
# 50%                        29.600000               3256.000000
# 75%                        31.800000               3330.825000
# max                        35.500000               3585.700000

# %%
birth_rates_df.dtypes
# Out:
# State                             object
# State Abbreviation                object
# Year                               int64
# Gender                            object
# Education Level of Mother         object
# Education Level Code               int64
# Number of Births                   int64
# Average Age of Mother (years)    float64
# Average Birth Weight (g)         float64
# dtype: object

# %%
z = birth_rates_df.drop(columns=["Gender", 'Education Level of Mother', 'State']).set_index('State Abbreviation').corr()
z2 = birth_rates_df.drop(columns=["Gender", 'Education Level of Mother', 'State', "State Abbreviation"]).groupby('Year').sum()
z4 = birth_rates_df.drop(columns=["Gender", 'State', 'Average Birth Weight (g)', 'State Abbreviation']).reset_index()
z4_cleaned = z4.groupby(['Year', 'Education Level of Mother', 'Education Level Code']).agg({"Number of Births":'sum', 'Average Age of Mother (years)':'mean'}).reset_index()

# %%
z3 = birth_rates_df.drop(columns=["Gender", 'Education Level of Mother', 'State', "State Abbreviation"])
z3
# Out:
#       Year  Education Level Code  Number of Births  \
# 0     2016                     1              1052
# 1     2016                     2              3436
# 2     2016                     3              8777
# 3     2016                     4              6453
# 4     2016                     5              2227
# ...    ...                   ...               ...
# 5491  2021                     5               401
# 5492  2021                     6               657
# 5493  2021                     7               261
# 5494  2021                     8                72
# 5495  2021                    -9                41
#
#       Average Age of Mother (years)  Average Birth Weight (g)
# 0                              27.8                    3116.9
# 1                              24.1                    3040.0
# 2                              25.4                    3080.0
# 3                              26.7                    3121.9
# 4                              28.9                    3174.3
# ...                             ...                       ...
# 5491                           29.2                    3261.1
# 5492                           30.7                    3286.0
# 5493                           33.0                    3249.3
# 5494                           33.3                    3262.0
# 5495                           29.2                    3177.5
#
# [5496 rows x 5 columns]

# %%
z4
# Out:
#       index  Year                          Education Level of Mother  \
# 0         0  2016                                  8th grade or less
# 1         1  2016             9th through 12th grade with no diploma
# 2         2  2016              High school graduate or GED completed
# 3         3  2016              Some college credit, but not a degree
# 4         4  2016                          Associate degree (AA, AS)
# ...     ...   ...                                                ...
# 5491   5491  2021                          Associate degree (AA, AS)
# 5492   5492  2021                     Bachelor's degree (BA, AB, BS)
# 5493   5493  2021      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# 5494   5494  2021  Doctorate (PhD, EdD) or Professional Degree (M...
# 5495   5495  2021                              Unknown or Not Stated
#
#       Education Level Code  Number of Births  Average Age of Mother (years)
# 0                        1              1052                           27.8
# 1                        2              3436                           24.1
# 2                        3              8777                           25.4
# 3                        4              6453                           26.7
# 4                        5              2227                           28.9
# ...                    ...               ...                            ...
# 5491                     5               401                           29.2
# 5492                     6               657                           30.7
# 5493                     7               261                           33.0
# 5494                     8                72                           33.3
# 5495                    -9                41                           29.2
#
# [5496 rows x 6 columns]

# %%
z4_df = pd.DataFrame(z4)

# %%
z4_df= z4_df.drop(columns='count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 z4_df= z4_df.drop(columns='count')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['count'] not found in axis"

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qw/b5rk3_jd0f71s0ysbqxl07sc0000gn/T/ipykernel_30077/4164777965.py in ?()
# ----> 1 z4_df.flatten()
#
# ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'flatten'

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

# Generate a large random dataset


# Compute the correlation matrix
corr = z

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
z2.plot(kind = 'line',y= 'Number of Births')
# Out:
# <Axes: xlabel='Year'>

# %%
corr = z

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
import seaborn.objects as so

# %%
(
    so.Plot(z2, x= z2.index, y='Number of Births')#, color="Country")
    .add(so.Line())
)

# %%
z4_cleaned= z4_cleaned.sort_values('Education Level Code', ascending=True)

# %%
(
    so.Plot(z4_cleaned,x= 'Year', y='Number of Births', color="Education Level of Mother")
    .add(so.Line())
)

# %%
import matplotx

f, ax = plt.subplots()
sns.lineplot(z4_cleaned,x= 'Year', y='Number of Births', hue="Education Level of Mother")
#pos = ax.get_position()
#ax.legend(loc='upper right', bbox_to_anchor=(2.13, .75))
matplotx.line_labels()

# %%
f, ax = plt.subplots(figsize=(11, 9))

sns.barplot(z4_cleaned,x= 'Number of Births', y= "Education Level of Mother", hue="Education Level of Mother")
ax.legend().set_visible(False)

# %%
g = so.Plot(z4_cleaned,x= "Education Level of Mother", y= 'Number of Births').add(so.Bar())
g.set_xticklabels('8th grade or less', rotation = 45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[176], line 2
#       1 g = so.Plot(z4_cleaned,x= "Education Level of Mother", y= 'Number of Births').add(so.Bar())
# ----> 2 g.set_xticklabels('8th grade or less', rotation = 45)
#
# AttributeError: 'Plot' object has no attribute 'set_xticklabels'

# %%
z3.plot(kind = 'bar')
fig, axs = plt.subplots(2,1)
axs[0]= z3.plot(kind= 'bar', y = "Number of Births", axs=axs[0])
axs[1]= z3.plot(kind= 'bar', y = ['Average Age of Mother (years)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 3
#       1 z3.plot(kind = 'bar')
#       2 fig, axs = plt.subplots(2,1)
# ----> 3 axs[0]= z3.plot(kind= 'bar', y = "Number of Births", axs=axs[0])
#       4 axs[1]= z3.plot(kind= 'bar', y = ['Average Age of Mother (years)'])
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1730, in BarPlot._make_plot(self)
#    1728 else:
#    1729     w = self.bar_width / K
# -> 1730     rect = self._plot(
#    1731         ax,
#    1732         self.ax_pos + (i + 0.5) * w,
#    1733         y,
#    1734         w,
#    1735         start=start,
#    1736         label=label,
#    1737         log=self.log,
#    1738         **kwds,
#    1739     )
#    1740 self._append_legend_handles_labels(rect, label)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1662, in BarPlot._plot(cls, ax, x, y, w, start, log, **kwds)
#    1651 @classmethod
#    1652 def _plot(  # type: ignore[override]
#    1653     cls,
#    (...)
#    1660     **kwds,
#    1661 ):
# -> 1662     return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2488, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2479 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2480     r = mpatches.Rectangle(
#    2481         xy=(l, b), width=w, height=h,
#    2482         facecolor=c,
#    (...)
#    2486         hatch=htch,
#    2487         )
# -> 2488     r._internal_update(kwargs)
#    2489     r.get_path()._interpolation_steps = 100
#    2490     if orientation == 'vertical':
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'axs'

# %%
# Get the figure and the axes
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(10,4))

b_avg = z3.groupby('Year')['Number of Births'].sum()
# Build the first plot
b_avg.plot(kind='bar', ax=ax0)
#ax0.set(title='Revenue', xlabel='Total revenue', ylabel='Customers')

# Add average line to the first plot
#revenue_average = top_10['Sales'].mean()
#ax0.axvline(x=revenue_average, color='r', label='Average', linestyle='--', linewidth=1)

# Build the second plot
#z3.plot(kind='bar', y='Average Age of Mother (years)', ax=ax1)
#ax1.set(title='Units', xlabel='Total units', ylabel='')

# Add average line to the second plot
#purchases_average = top_10['Purchases'].mean()
#ax1.axvline(x=purchases_average, color='r', label='Average', linestyle='--', linewidth=1)

# Title the figure
fig.suptitle('US Birth Rate', fontsize=14, fontweight='bold')

# Hide the plot legends
ax0.legend().set_visible(False)
ax1.legend().set_visible(False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
b_avg = z3.groupby('Year')['Number of Births'].sum()
b_avg
# Out:
# Year
# 2016    3945853
# 2017    3855479
# 2018    3791707
# 2019    3747531
# 2020    3613633
# 2021    3664277
# Name: Number of Births, dtype: int64

# %%
z4 = birth_rates_df.drop(columns=["Gender", 'State', 'Average Birth Weight (g)', 'State Abbreviation']).reset_index()
z4_cleaned = z4.groupby(['Year', 'Education Level of Mother', 'Education Level Code']).agg({"Number of Births":'sum', 'Average Age of Mother (years)':'mean'}).reset_index()
z4_cleaned= z4_cleaned.sort_values(by = ['Year', 'Education Level Code'], ascending = [True, True])
z4_cleaned.head()
# Out:
#    Year               Education Level of Mother  Education Level Code  \
# 8  2016                   Unknown or Not Stated                    -9
# 0  2016                       8th grade or less                     1
# 1  2016  9th through 12th grade with no diploma                     2
# 5  2016   High school graduate or GED completed                     3
# 7  2016   Some college credit, but not a degree                     4
#
#    Number of Births  Average Age of Mother (years)
# 8             51477                      29.157576
# 0            132090                      29.193137
# 1            406561                      24.710784
# 5            979820                      26.206863
# 7            807772                      27.652941

# %%
sns.barplot(data=z4_cleaned, y="Education Level of Mother", x="Number of Births")
# Out:
# <Axes: xlabel='Number of Births', ylabel='Education Level of Mother'>
