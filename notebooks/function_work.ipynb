# %%
# in your notebook cell
import sys

# path relative to your notebook
sys.path.insert(0, '../src')

# import as usual
import numpy as np
import function as f
# autoreload

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
birth_df = function.create_df_from_csv('../data/us_births_2016_2021.csv')
birth_extended = function.create_df_from_csv('../data/Natality, 2007-2021.txt')
birth_df
# Out:
#         State State Abbreviation  Year Gender  \
# 0     Alabama                 AL  2016      F
# 1     Alabama                 AL  2016      F
# 2     Alabama                 AL  2016      F
# 3     Alabama                 AL  2016      F
# 4     Alabama                 AL  2016      F
# ...       ...                ...   ...    ...
# 5491  Wyoming                 WY  2021      M
# 5492  Wyoming                 WY  2021      M
# 5493  Wyoming                 WY  2021      M
# 5494  Wyoming                 WY  2021      M
# 5495  Wyoming                 WY  2021      M
#
#                               Education Level of Mother  Education Level Code  \
# 0                                     8th grade or less                     1
# 1                9th through 12th grade with no diploma                     2
# 2                 High school graduate or GED completed                     3
# 3                 Some college credit, but not a degree                     4
# ...

# %%
fieldstoremove= ['Notes','State Code', 'Year Code', 'Marital Status Code', 'Tobacco Use Code', 'Diabetes Code']
birth_extended1 = f.remove_field(fieldstoremove, birth_extended)
birth_extended2 = birth_extended1.drop(index=[3303, 3310, 3318, 3393, 3417, 5636])

# %%
ave = list(birth_extended2['Average Birth Weight'])
ave
average= []
for i in ave:
    average.append(float(i))

# %%
# Out:
# 376.22

# %%
new = f.grams_to_lbs_in_df(birth_df, 'Average Birth Weight (g)')
new
# Out:
#         State State Abbreviation  Year Gender  \
# 0     Alabama                 AL  2016      F
# 1     Alabama                 AL  2016      F
# 2     Alabama                 AL  2016      F
# 3     Alabama                 AL  2016      F
# 4     Alabama                 AL  2016      F
# ...       ...                ...   ...    ...
# 5491  Wyoming                 WY  2021      M
# 5492  Wyoming                 WY  2021      M
# 5493  Wyoming                 WY  2021      M
# 5494  Wyoming                 WY  2021      M
# 5495  Wyoming                 WY  2021      M
#
#                               Education Level of Mother  Education Level Code  \
# 0                                     8th grade or less                     1
# 1                9th through 12th grade with no diploma                     2
# 2                 High school graduate or GED completed                     3
# 3                 Some college credit, but not a degree                     4
# ...
